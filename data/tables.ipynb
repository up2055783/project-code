# %%
from great_tables import GT
import pandas as pd

# %%
df_a = pd.read_csv("beads_data_with_dose.csv")
df_b = pd.read_csv("fading effect/fading_data_with_adjusted_counts.csv")

# %%
print(df_a.columns)
print(df_b.columns)
# Out:
# Index(['group', 'bead_size', 'bead_number', 'bead_id', 'experiment',
#        'e_factor', 'beam_energy', 'dose_level', 'exp_variable', 'scf_count',
#        'raw_bead', 'scf_bead', 'calibrated_count', 'is_control',
#        'mean_control', 'adjusted_count', 'dose'],
#       dtype='str')
# Index(['group', 'bg_reading', 'bead_size', 'bead_number', 'scf_bead',
#        'raw_bead', 'mean_control', 'calibrated_count', 'adjusted_count'],
#       dtype='str')

# %%
#first table - linearity
#want data for bead_size, bead_id, beam_energy, dose_level, scf_count, raw_bead, scf_bead, calibrated_count
#mean_control, adjusted_count, dose

linearity_df = df[df_a["experiment"] == "linearity"]
linearity_df.head()
len(linearity_df)
# Out:
# 217

# %%
clean_linearity_df = df.drop([ 'group', "experiment", "e_factor", "exp_variable", "is_control"
], axis=1)
clean_linearity_df.head()


df_a_clean = df_a.drop([ 'group', "experiment", "e_factor", "exp_variable", "is_control"], axis=1)

# %%
lin1_df= clean_linearity_df[
    (clean_linearity_df["bead_number"] >= 1) &
    (clean_linearity_df["bead_number"] <= 30) & (clean_linearity_df["bead_size"] == 1.0 )
]

# %%
gt_tbl_1 = GT(lin1_df)

gt_tbl_1
gt_tbl_1.save("linearity1_table.png")
# Out:
# GT(_tbl_data=    bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 0         1.0            1     1_1          6.0        10.0      40.85
# 1         1.0            2     1_2          6.0        10.0      40.84
# 2         1.0            3     1_3          6.0        10.0      40.75
# 3         1.0            4     1_4          6.0        10.0      42.97
# 4         1.0            5     1_5          6.0        10.0      43.52
# 5         1.0            6     1_6          6.0        25.0      41.46
# 6         1.0            7     1_7          6.0        25.0      40.44
# 7         1.0           10    1_10          6.0        25.0      39.96
# 8         1.0           11     2_1          6.0        25.0      41.84
# 9         1.0           12     2_2          6.0        50.0      41.72
# 10        1.0           13     2_3          6.0        50.0      38.50
# 11        1.0           14     2_4          6.0        50.0      41.85
# ...

# %%
lin2_df= clean_linearity_df[
    (clean_linearity_df["bead_number"] >= 31) &
    (clean_linearity_df["bead_number"] <= 60) & (clean_linearity_df["bead_size"] == 1.0 )
]

gt_tbl_2 = GT(lin2_df)

gt_tbl_2
gt_tbl_2.save("linearity2_table.png")
# Out:
# GT(_tbl_data=    bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 28        1.0           31     4_1          6.0       500.0      36.81
# 29        1.0           32     4_2          6.0      1000.0      39.36
# 30        1.0           33     4_3          6.0      1000.0      39.90
# 31        1.0           34     4_4          6.0      1000.0      40.40
# 32        1.0           35     4_5          6.0      1000.0      39.61
# 33        1.0           36     4_6          6.0      1000.0      41.80
# 34        1.0           37     4_7          6.0      2000.0      42.97
# 35        1.0           38     4_8          6.0      2000.0      39.77
# 36        1.0           39     4_9          6.0      2000.0      39.56
# 37        1.0           40    4_10          6.0      2000.0      38.88
# 38        1.0           41     5_1          6.0      2000.0      40.16
# 39        1.0           42     5_2          6.0      3000.0      42.34
# ...

# %%
lin3_df= clean_linearity_df[
    (clean_linearity_df["bead_number"] >= 61) &
    (clean_linearity_df["bead_number"] <= 90) & (clean_linearity_df["bead_size"] == 1.0 )
]

gt_tbl_3 = GT(lin3_df)

gt_tbl_3
gt_tbl_3.save("linearity3_table.png")
# Out:
# GT(_tbl_data=    bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 56        1.0           61     7_1         10.0        10.0      39.21
# 57        1.0           62     7_2         10.0        10.0      37.28
# 58        1.0           64     7_4         10.0        25.0      39.03
# 59        1.0           65     7_5         10.0        25.0      37.60
# 60        1.0           66     7_6         10.0        25.0      38.13
# 61        1.0           67     7_7         10.0        25.0      37.51
# 62        1.0           68     7_8         10.0        25.0      38.42
# 63        1.0           69     7_9         10.0        50.0      37.94
# 64        1.0           70    7_10         10.0        50.0      38.90
# 65        1.0           71     8_1         10.0        50.0      38.70
# 66        1.0           72     8_2         10.0        50.0      39.44
# 67        1.0           73     8_3         10.0        50.0      38.07
# ...

# %%
lin4_df= clean_linearity_df[
    (clean_linearity_df["bead_number"] >= 91) &
    (clean_linearity_df["bead_number"] <= 114) & (clean_linearity_df["bead_size"] == 1.0 )
]

gt_tbl_4 = GT(lin4_df)

gt_tbl_4
gt_tbl_4.save("linearity4_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 84         1.0           91    10_1         10.0      1000.0      43.81
# 85         1.0           92    10_2         10.0      1000.0      40.92
# 86         1.0           93    10_3         10.0      1000.0      46.76
# 87         1.0           94    10_4         10.0      1000.0      37.46
# 88         1.0           95    10_5         10.0      2000.0      37.54
# 89         1.0           96    10_6         10.0      2000.0      38.14
# 90         1.0           97    10_7         10.0      2000.0      39.69
# 91         1.0           98    10_8         10.0      2000.0      37.62
# 92         1.0           99    10_9         10.0      2000.0      37.88
# 93         1.0          100   10_10         10.0      3000.0      38.59
# 94         1.0          101    11_1         10.0      3000.0      41.49
# 95         1.0          102    11_2         10.0      3000.0      45.95
# ...

# %%
lin5_df= clean_linearity_df[
    (clean_linearity_df["bead_number"] >= 1) &
    (clean_linearity_df["bead_number"] <= 30) & (clean_linearity_df["bead_size"] == 1.5 )
]

gt_tbl_5 = GT(lin5_df)

gt_tbl_5
gt_tbl_5.save("linearity5_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 230        1.5            1     1_1          6.0        10.0     110.20
# 231        1.5            2     1_2          6.0        10.0     109.60
# 232        1.5            3     1_3          6.0        10.0     103.20
# 233        1.5            4     1_4          6.0        10.0     108.30
# 234        1.5            5     1_5          6.0        10.0     107.20
# 235        1.5            6     1_6          6.0        25.0     114.60
# 236        1.5            7     1_7          6.0        25.0     114.50
# 237        1.5            8     1_8          6.0        25.0     117.20
# 238        1.5            9     1_9          6.0        25.0     113.50
# 239        1.5           10    1_10          6.0        25.0     102.00
# 240        1.5           11     2_1          6.0        50.0     115.00
# 241        1.5           12     2_2          6.0        50.0     111.50
# ...

# %%
lin6_df= clean_linearity_df[
    (clean_linearity_df["bead_number"] >= 31) &
    (clean_linearity_df["bead_number"] <= 60) & (clean_linearity_df["bead_size"] == 1.5 )
]

gt_tbl_6 = GT(lin6_df)

gt_tbl_6
gt_tbl_6.save("linearity6_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 260        1.5           31     4_1          6.0      1000.0     112.80
# 261        1.5           32     4_2          6.0      1000.0     106.90
# 262        1.5           33     4_3          6.0      1000.0     111.10
# 263        1.5           34     4_4          6.0      1000.0     113.40
# 264        1.5           35     4_5          6.0      1000.0     109.90
# 265        1.5           36     4_6          6.0      2000.0     110.30
# 266        1.5           37     4_7          6.0      2000.0     111.00
# 267        1.5           38     4_8          6.0      2000.0     108.90
# 268        1.5           39     4_9          6.0      2000.0     107.40
# 269        1.5           40    4_10          6.0      2000.0     109.80
# 270        1.5           41     5_1          6.0      3000.0     105.50
# 271        1.5           42     5_2          6.0      3000.0     118.50
# ...

# %%
lin7_df= clean_linearity_df[
    (clean_linearity_df["bead_number"] >= 61) &
    (clean_linearity_df["bead_number"] <= 90) & (clean_linearity_df["bead_size"] == 1.5 )
]

gt_tbl_7 = GT(lin7_df)

gt_tbl_7
gt_tbl_7.save("linearity7_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 290        1.5           61     7_1         10.0        25.0     115.20
# 291        1.5           62     7_2         10.0        25.0     106.50
# 292        1.5           63     7_3         10.0        25.0     109.00
# 293        1.5           64     7_4         10.0        25.0      92.58
# 294        1.5           65     7_5         10.0        25.0     108.70
# 295        1.5           66     7_6         10.0        50.0      96.48
# 296        1.5           67     7_7         10.0        50.0     106.80
# 297        1.5           68     7_8         10.0        50.0     109.60
# 298        1.5           69     7_9         10.0        50.0     110.30
# 299        1.5           70    7_10         10.0        50.0     110.60
# 300        1.5           71     8_1         10.0       100.0     111.70
# 301        1.5           72     8_2         10.0       100.0     107.70
# ...

# %%
lin8_df= clean_linearity_df[
    (clean_linearity_df["bead_number"] >= 91) &
    (clean_linearity_df["bead_number"] <= 110) & (clean_linearity_df["bead_size"] == 1.5 )
]

gt_tbl_8 = GT(lin8_df)

gt_tbl_8
gt_tbl_8.save("linearity8_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 320        1.5           91    10_1         10.0      2000.0      111.5
# 321        1.5           92    10_2         10.0      2000.0      109.8
# 322        1.5           93    10_3         10.0      2000.0      108.8
# 323        1.5           94    10_4         10.0      2000.0      109.5
# 324        1.5           95    10_5         10.0      2000.0      107.6
# 325        1.5           96    10_6         10.0      3000.0      108.7
# 326        1.5           97    10_7         10.0      3000.0      110.2
# 327        1.5           98    10_8         10.0      3000.0      112.7
# 328        1.5           99    10_9         10.0      3000.0      105.7
# 329        1.5          100   10_10         10.0      3000.0      106.2
# 330        1.5          101    11_1         10.0      5000.0      104.2
# 331        1.5          102    11_2         10.0      5000.0      112.3
# ...

# %%
dr1_df = df_a_clean[
    (df_a_clean["bead_number"] >= 115) &
    (df_a_clean["bead_number"] <= 145) &
    (df_a_clean["bead_size"] == 1.0)
]

gt_tbl_9 = GT(dr1_df)

gt_tbl_9

gt_tbl_9.save("doserate1_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 107        1.0          115    12_5          6.0       200.0      37.63
# 108        1.0          116    12_6          6.0       200.0      36.80
# 109        1.0          117    12_7          6.0       200.0      37.69
# 110        1.0          118    12_8          6.0       200.0      37.88
# 111        1.0          119    12_9          6.0       200.0      38.52
# 112        1.0          120   12_10          6.0       200.0      39.33
# 113        1.0          122    13_2          6.0       200.0      45.33
# 114        1.0          123    13_3          6.0       200.0      37.97
# 115        1.0          124    13_4          6.0       200.0      40.04
# 116        1.0          125    13_5          6.0       200.0      38.52
# 117        1.0          126    13_6          6.0       200.0      37.60
# 118        1.0          127    13_7          6.0       200.0      40.63
# ...

# %%
dr2_df = df_a_clean[
    (df_a_clean["bead_number"] >= 146) &
    (df_a_clean["bead_number"] <= 175) &
    (df_a_clean["bead_size"] == 1.0)
]

gt_tbl_10 = GT(dr2_df)

gt_tbl_10

gt_tbl_10.save("doserate2_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 137        1.0          146    15_6          6.0       200.0      39.30
# 138        1.0          147    15_7          6.0       200.0      38.66
# 139        1.0          148    15_8          6.0       200.0      39.49
# 140        1.0          149    15_9          6.0       200.0      39.57
# 141        1.0          150   15_10          6.0       200.0      39.30
# 142        1.0          151    16_1          6.0       200.0      40.42
# 143        1.0          152    16_2          6.0       200.0      36.10
# 144        1.0          153    16_3          6.0       200.0      48.04
# 145        1.0          154    16_4          6.0       200.0      38.39
# 146        1.0          155    16_5          6.0       200.0      38.00
# 147        1.0          156    16_6          6.0       200.0      37.85
# 148        1.0          157    16_7          6.0       200.0      38.02
# ...

# %%
dr3_df = df_a_clean[
    (df_a_clean["bead_number"] >= 176) &
    (df_a_clean["bead_number"] <= 198) &
    (df_a_clean["bead_size"] == 1.0)
]

gt_tbl_11 = GT(dr3_df)

gt_tbl_11

gt_tbl_11.save("doserate3_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 163        1.0          176    18_6         10.0       200.0      38.72
# 164        1.0          177    18_7         10.0       200.0      37.68
# 165        1.0          178    18_8         10.0       200.0      43.81
# 166        1.0          179    18_9         10.0       200.0      38.15
# 167        1.0          180   18_10         10.0       200.0      38.12
# 168        1.0          181    19_1         10.0       200.0      40.46
# 169        1.0          182    19_2         10.0       200.0      38.59
# 170        1.0          183    19_3         10.0       200.0      37.57
# 171        1.0          184    19_4         10.0       200.0      39.95
# 172        1.0          185    19_5         10.0       200.0      41.33
# 173        1.0          186    19_6         10.0       200.0      39.31
# 174        1.0          187    19_7         10.0       200.0      37.92
# ...

# %%
dr4_df = df_a_clean[
    (df_a_clean["bead_number"] >= 111) &
    (df_a_clean["bead_number"] <= 140) &
    (df_a_clean["bead_size"] == 1.5)
]

gt_tbl_12 = GT(dr4_df)

gt_tbl_12

gt_tbl_12.save("doserate4_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 340        1.5          111    12_1          6.0       200.0     104.40
# 341        1.5          112    12_2          6.0       200.0     105.60
# 342        1.5          113    12_3          6.0       200.0      99.24
# 343        1.5          114    12_4          6.0       200.0     103.40
# 344        1.5          115    12_5          6.0       200.0     102.20
# 345        1.5          116    12_6          6.0       200.0     108.10
# 346        1.5          117    12_7          6.0       200.0      95.26
# 347        1.5          118    12_8          6.0       200.0     101.10
# 348        1.5          119    12_9          6.0       200.0     101.90
# 349        1.5          120   12_10          6.0       200.0      96.06
# 350        1.5          121    13_1          6.0       200.0     109.30
# 351        1.5          122    13_2          6.0       200.0     108.80
# ...

# %%
dr5_df = df_a_clean[
    (df_a_clean["bead_number"] >= 141) &
    (df_a_clean["bead_number"] <= 170) &
    (df_a_clean["bead_size"] == 1.5)
]

gt_tbl_13 = GT(dr5_df)

gt_tbl_13

gt_tbl_13.save("doserate5_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 370        1.5          141    15_1          6.0       200.0     107.60
# 371        1.5          142    15_2          6.0       200.0     105.70
# 372        1.5          143    15_3          6.0       200.0     109.50
# 373        1.5          144    15_4          6.0       200.0     101.70
# 374        1.5          145    15_5          6.0       200.0     104.30
# 375        1.5          146    15_6          6.0       200.0     106.90
# 376        1.5          147    15_7          6.0       200.0     105.00
# 377        1.5          148    15_8          6.0       200.0     102.90
# 378        1.5          149    15_9          6.0       200.0      98.52
# 379        1.5          150   15_10          6.0       200.0     102.40
# 380        1.5          151    16_1          6.0       200.0     109.00
# 381        1.5          152    16_2          6.0       200.0     107.20
# ...

# %%
dr6_df = df_a_clean[
    (df_a_clean["bead_number"] >= 171) &
    (df_a_clean["bead_number"] <= 190) &
    (df_a_clean["bead_size"] == 1.5)
]

gt_tbl_14 = GT(dr6_df)

gt_tbl_14

gt_tbl_14.save("doserate6_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 400        1.5          171    18_1         10.0       200.0     101.60
# 401        1.5          172    18_2         10.0       200.0     106.30
# 402        1.5          173    18_3         10.0       200.0     102.30
# 403        1.5          174    18_4         10.0       200.0     100.80
# 404        1.5          175    18_5         10.0       200.0      98.79
# 405        1.5          176    18_6         10.0       200.0      95.29
# 406        1.5          177    18_7         10.0       200.0      95.94
# 407        1.5          178    18_8         10.0       200.0     100.80
# 408        1.5          179    18_9         10.0       200.0     100.90
# 409        1.5          180   18_10         10.0       200.0     104.50
# 410        1.5          181    19_1         10.0       200.0     103.00
# 411        1.5          182    19_2         10.0       200.0     101.30
# ...

# %%
er1_df = df_a_clean[
    (df_a_clean["bead_number"] >= 200) &
    (df_a_clean["bead_number"] <= 230) &
    (df_a_clean["bead_size"] == 1.0)
]

gt_tbl_15 = GT(er1_df)

gt_tbl_15

gt_tbl_15.save("energyresponse1_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 185        1.0          210   21_10         0.06       200.0      38.83
# 186        1.0          211    22_1         0.06       200.0      40.61
# 187        1.0          212    22_2         0.06       200.0      36.19
# 188        1.0          213    22_3         0.06       200.0      36.96
# 189        1.0          214    22_4         0.06       200.0      39.40
# 190        1.0          215    22_5         0.10       200.0      40.85
# 191        1.0          216    22_6         0.10       200.0      36.84
# 192        1.0          217    22_7         0.10       200.0      40.11
# 193        1.0          218    22_8         0.10       200.0      39.06
# 194        1.0          219    22_9         0.10       200.0      39.50
# 195        1.0          220   22_10         0.18       200.0      38.85
# 196        1.0          221    23_1         0.18       200.0      39.57
# ...

# %%
er2_df = df_a_clean[
    (df_a_clean["bead_number"] >= 231) &
    (df_a_clean["bead_number"] <= 254) &
    (df_a_clean["bead_size"] == 1.0)
]

gt_tbl_16 = GT(er2_df)

gt_tbl_16

gt_tbl_16.save("energyresponse2_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 206        1.0          231    24_1         0.15       200.0      38.09
# 207        1.0          232    24_2         0.15       200.0      37.50
# 208        1.0          233    24_3         0.15       200.0      39.16
# 209        1.0          234    24_4         0.15       200.0      37.38
# 210        1.0          235    24_5         6.00       200.0      38.74
# 211        1.0          236    24_6         6.00       200.0      37.58
# 212        1.0          237    24_7         6.00       200.0      38.20
# 213        1.0          238    24_8         6.00       200.0      38.61
# 214        1.0          239    24_9         6.00       200.0      38.13
# 215        1.0          240   24_10        10.00       200.0      38.39
# 216        1.0          241    25_1        10.00       200.0      37.15
# 217        1.0          242    25_2        10.00       200.0      38.18
# ...

# %%
er3_df = df_a_clean[
    (df_a_clean["bead_number"] >= 201) &
    (df_a_clean["bead_number"] <= 230) &
    (df_a_clean["bead_size"] == 1.5)
]

gt_tbl_17 = GT(er3_df)

gt_tbl_17

gt_tbl_17.save("energyresponse3_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 420        1.5          201    21_1         0.06       200.0      97.41
# 421        1.5          202    21_2         0.06       200.0     102.70
# 422        1.5          203    21_3         0.06       200.0     103.30
# 423        1.5          204    21_4         0.06       200.0     105.70
# 424        1.5          205    21_5         0.06       200.0     102.10
# 425        1.5          207    21_7         0.10       200.0     103.10
# 426        1.5          208    21_8         0.10       200.0      97.65
# 427        1.5          209    21_9         0.10       200.0     108.60
# 428        1.5          210   21_10         0.10       200.0     103.90
# 429        1.5          211    22_1         0.10       200.0     106.70
# 430        1.5          212    22_2         0.15       200.0     104.40
# 431        1.5          213    22_3         0.15       200.0     104.10
# ...

# %%
er4_df = df_a_clean[
    (df_a_clean["bead_number"] >= 231) &
    (df_a_clean["bead_number"] <= 248) &
    (df_a_clean["bead_size"] == 1.5)
]

gt_tbl_18 = GT(er4_df)

gt_tbl_18

gt_tbl_18.save("energyresponse4_table.png")
# Out:
# GT(_tbl_data=     bead_size  bead_number bead_id  beam_energy  dose_level  scf_count  \
# 447        1.5          231    24_1          6.0       200.0      95.21
# 448        1.5          232    24_2          6.0       200.0     102.30
# 449        1.5          233    24_3          6.0       200.0     101.90
# 450        1.5          234    24_4         10.0       200.0     102.00
# 451        1.5          235    24_5         10.0       200.0      96.56
# 452        1.5          236    24_6         10.0       200.0     104.40
# 453        1.5          237    24_7         10.0       200.0     108.20
# 454        1.5          238    24_8         10.0       200.0     104.10
# 455        1.5          239    24_9         10.0       200.0     104.20
# 456        1.5          240   24_10         10.0       200.0     101.90
# 457        1.5          241    25_1         10.0       200.0     102.80
# 458        1.5          242    25_2         10.0       200.0      97.40
# ...

# %%
fe1_df = df_b[
    (df_b["group"] >= 1) &
    (df_b["group"] <= 7) &
    (df_b["bead_size"] == 1.0)
]

gt_tbl_19 = GT(fe1_df)

gt_tbl_19

gt_tbl_19.save("fadingeffect1_table.png")
# Out:
# GT(_tbl_data=    group  bg_reading  bead_size bead_number  scf_bead  raw_bead  \
# 0     1.0    0.206917        1.0         1_1  0.976572     67.49
# 1     1.0    0.206917        1.0         1_2  0.976812     56.99
# 2     1.0    0.206917        1.0         1_3  0.978980     54.90
# 3     1.0    0.206917        1.0         1_4  0.928171     53.84
# 4     1.0    0.206917        1.0         1_5  0.916388     55.39
# 5     2.0    0.206917        1.0         1_6  0.962135     51.44
# 6     2.0    0.206917        1.0         1_7  0.986521     55.05
# 7     2.0    0.206917        1.0        1_10  0.998429     51.20
# 8     2.0    0.206917        1.0         2_1  0.953356     53.33
# 9     3.0    0.206917        1.0         2_3  1.036485     54.20
# 10    3.0    0.206917        1.0         2_4  0.953127     53.17
# 11    3.0    0.206917        1.0         2_5  0.982371     51.87
# 12    3.0    0.206917        1.0         2_6  0.996925     55.97
# ...

# %%
fe2_df = df_b[
    (df_b["group"] >= 8) &
    (df_b["group"] <= 14) &
    (df_b["bead_size"] == 1.0)
]

gt_tbl_20 = GT(fe2_df)

gt_tbl_20

gt_tbl_20.save("fadingeffect2_table.png")
# Out:
# GT(_tbl_data=    group  bg_reading  bead_size bead_number  scf_bead  raw_bead  \
# 33    8.0    0.210000        1.0         5_2  0.942045     49.86
# 34    8.0    0.210000        1.0         5_3  0.985297     53.34
# 35    8.0    0.210000        1.0         5_4  0.962835     48.35
# 36    8.0    0.210000        1.0         5_5  0.976092     48.82
# 37    8.0    0.210000        1.0         5_6  0.967528     46.70
# 38    9.0    0.221683        1.0         5_7  1.007295     48.37
# 39    9.0    0.221683        1.0         5_8  0.974893     47.45
# 40    9.0    0.221683        1.0         6_1  0.942045     47.71
# 41    9.0    0.221683        1.0         6_2  0.923851     49.76
# 42    9.0    0.221683        1.0         6_3  1.002463     48.21
# 43   10.0    0.231200        1.0         6_4  1.017623     42.86
# 44   10.0    0.231200        1.0         6_5  1.039742     46.20
# 45   10.0    0.231200        1.0         6_6  1.003476     46.33
# ...

# %%
fe3_df = df_b[
    (df_b["group"] >= 1) &
    (df_b["group"] <= 7) &
    (df_b["bead_size"] == 1.5)
]

gt_tbl_21 = GT(fe3_df)

gt_tbl_21

gt_tbl_21.save("fadingeffect3_table.png")
# Out:
# GT(_tbl_data=     group  bg_reading  bead_size bead_number  scf_bead  raw_bead  \
# 68     1.0    0.206917        1.5         1_1  0.981135     145.4
# 69     1.0    0.206917        1.5         1_2  0.986515     139.2
# 70     1.0    0.206917        1.5         1_3  1.047811     133.3
# 71     1.0    0.206917        1.5         1_4  0.998379     138.8
# 72     1.0    0.206917        1.5         1_5  1.008642     129.0
# 73     2.0    0.206917        1.5         1_6  0.943400     143.2
# 74     2.0    0.206917        1.5         1_7  0.944226     128.2
# 75     2.0    0.206917        1.5         1_8  0.922437     145.1
# 76     2.0    0.206917        1.5         1_9  0.952559     137.8
# 77     2.0    0.206917        1.5        1_10  1.060162     138.3
# 78     3.0    0.206917        1.5         2_1  0.940113     135.8
# 79     3.0    0.206917        1.5         2_2  0.969675     134.2
# 80     3.0    0.206917        1.5         2_3  0.991045     136.6
# ...

# %%
fe4_df = df_b[
    (df_b["group"] >= 8) &
    (df_b["group"] <= 14) &
    (df_b["bead_size"] == 1.5)
]

gt_tbl_22 = GT(fe4_df)

gt_tbl_22

gt_tbl_22.save("fadingeffect4_table.png")
# Out:
# GT(_tbl_data=     group  bg_reading  bead_size bead_number  scf_bead  raw_bead  \
# 103    8.0    0.210000        1.5         4_6  0.980244    126.30
# 104    8.0    0.210000        1.5         4_7  0.974051    126.90
# 105    8.0    0.210000        1.5         4_8  0.992868    127.60
# 106    8.0    0.210000        1.5         4_9  1.006760    118.40
# 107    8.0    0.210000        1.5        4_10  0.984715    124.10
# 108    9.0    0.221683        1.5         5_1  1.024925    119.70
# 109    9.0    0.221683        1.5         5_2  0.912300    119.10
# 110    9.0    0.221683        1.5         5_3  0.916951    117.60
# 111    9.0    0.221683        1.5         5_4  0.994698    118.20
# 112    9.0    0.221683        1.5         5_6  1.030798    115.10
# 113   10.0    0.231200        1.5         5_7  0.955088    116.40
# 114   10.0    0.231200        1.5         5_8  0.977580    114.80
# 115   10.0    0.231200        1.5         5_9  0.913072    123.50
# ...
